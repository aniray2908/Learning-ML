# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Anisha Ray\Downloads\train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
inputs = df.drop('Survived',axis='columns')

# %%
target = df.Survived

# %%
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
inputs['Sex_n'] = le.fit_transform(inputs['Sex'])

# %%
inputs.drop('Sex',axis='columns',inplace=True)
inputs.head()
# Out:
#    Pclass   Age     Fare  Sex_n
# 0       3  22.0   7.2500      1
# 1       1  38.0  71.2833      0
# 2       3  26.0   7.9250      0
# 3       1  35.0  53.1000      0
# 4       3  35.0   8.0500      1

# %%
inputs.notnull()
# Out:
#      Pclass    Age  Fare  Sex_n
# 0      True   True  True   True
# 1      True   True  True   True
# 2      True   True  True   True
# 3      True   True  True   True
# 4      True   True  True   True
# ..      ...    ...   ...    ...
# 886    True   True  True   True
# 887    True   True  True   True
# 888    True  False  True   True
# 889    True   True  True   True
# 890    True   True  True   True
#
# [891 rows x 4 columns]

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())

# %%
inputs.notnull()
# Out:
#      Pclass   Age  Fare  Sex_n
# 0      True  True  True   True
# 1      True  True  True   True
# 2      True  True  True   True
# 3      True  True  True   True
# 4      True  True  True   True
# ..      ...   ...   ...    ...
# 886    True  True  True   True
# 887    True  True  True   True
# 888    True  True  True   True
# 889    True  True  True   True
# 890    True  True  True   True
#
# [891 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7757847533632287

# %%
model.predict([[3,20,5,0]])
# Out:
# array([0], dtype=int64)

# %%
model.predict([[2,20,100,1]])
# Out:
# array([0], dtype=int64)

# %%
model.predict([[3,20,100,1]])
# Out:
# array([0], dtype=int64)

# %%
model.predict([[2,20,100,0]])
# Out:
# array([1], dtype=int64)

# %%
model.predict([[2,80,100,1]])
# Out:
# array([0], dtype=int64)

# %%
testdata = pd.read_csv(r"C:\Users\Anisha Ray\Downloads\test.csv")

# %%
testdata.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
passengerid = testdata.PassengerId
passengerid
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
testdata.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %%
testdata['Sex_n'] = le.fit_transform(testdata['Sex'])
testdata.head()
# Out:
#    Pclass     Sex   Age     Fare  Sex_n
# 0       3    male  34.5   7.8292      1
# 1       3  female  47.0   7.0000      0
# 2       2    male  62.0   9.6875      1
# 3       3    male  27.0   8.6625      1
# 4       3  female  22.0  12.2875      0

# %%
testdata_n = testdata.drop('Sex',axis='columns',inplace=True)

# %%
testdata.notnull()
# Out:
#      Pclass    Age  Fare  Sex_n
# 0      True   True  True   True
# 1      True   True  True   True
# 2      True   True  True   True
# 3      True   True  True   True
# 4      True   True  True   True
# ..      ...    ...   ...    ...
# 413    True  False  True   True
# 414    True   True  True   True
# 415    True   True  True   True
# 416    True  False  True   True
# 417    True  False  True   True
#
# [418 rows x 4 columns]

# %%
testdata.Age = testdata.Age.fillna(testdata.Age.mean())

# %%
testdata.notnull()
# Out:
#      Pclass   Age  Fare  Sex_n
# 0      True  True  True   True
# 1      True  True  True   True
# 2      True  True  True   True
# 3      True  True  True   True
# 4      True  True  True   True
# ..      ...   ...   ...    ...
# 413    True  True  True   True
# 414    True  True  True   True
# 415    True  True  True   True
# 416    True  True  True   True
# 417    True  True  True   True
#
# [418 rows x 4 columns]

# %%
testdata
# Out:
#      Pclass       Age      Fare  Sex_n
# 0         3  34.50000    7.8292      1
# 1         3  47.00000    7.0000      0
# 2         2  62.00000    9.6875      1
# 3         3  27.00000    8.6625      1
# 4         3  22.00000   12.2875      0
# ..      ...       ...       ...    ...
# 413       3  30.27259    8.0500      1
# 414       1  39.00000  108.9000      0
# 415       3  38.50000    7.2500      1
# 416       3  30.27259    8.0500      1
# 417       3  30.27259   22.3583      1
#
# [418 rows x 4 columns]

# %%
testdata.Fare = testdata.Fare.fillna(testdata.Fare.mean())

# %%
predict = model.predict(testdata)

# %%
testdata['Survived'] = predict

# %%
testdata
# Out:
#      Pclass       Age      Fare  Sex_n  Survived
# 0         3  34.50000    7.8292      1         0
# 1         3  47.00000    7.0000      0         0
# 2         2  62.00000    9.6875      1         1
# 3         3  27.00000    8.6625      1         0
# 4         3  22.00000   12.2875      0         1
# ..      ...       ...       ...    ...       ...
# 413       3  30.27259    8.0500      1         0
# 414       1  39.00000  108.9000      0         1
# 415       3  38.50000    7.2500      1         0
# 416       3  30.27259    8.0500      1         0
# 417       3  30.27259   22.3583      1         0
#
# [418 rows x 5 columns]

# %%
testdata.drop(['Age','Pclass','Fare','Sex_n'],axis='columns',inplace=True)

# %%
testdata
# Out:
#      Survived
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]

# %%
testdata['PassengerId'] = passengerid

# %%
testdata
# Out:
#      Survived  PassengerId
# 0           0          892
# 1           0          893
# 2           1          894
# 3           0          895
# 4           1          896
# ..        ...          ...
# 413         0         1305
# 414         1         1306
# 415         0         1307
# 416         0         1308
# 417         0         1309
#
# [418 rows x 2 columns]

# %%
testdata
# Out:
#      Survived  PassengerId
# 0           0          892
# 1           0          893
# 2           1          894
# 3           0          895
# 4           1          896
# ..        ...          ...
# 413         0         1305
# 414         1         1306
# 415         0         1307
# 416         0         1308
# 417         0         1309
#
# [418 rows x 2 columns]
